# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
vpp = pd.read_csv("D:\ML Project\Vehicle Performance Prediction\Dataset\data.csv")

# %%
vpp.describe()
# Out:
#            origin   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean     1.572864    5.454774    193.425879  2970.424623     15.568090
# std      0.802055    1.701004    104.269838   846.841774      2.757689
# min      1.000000    3.000000     68.000000  1613.000000      8.000000
# 25%      1.000000    4.000000    104.250000  2223.750000     13.825000
# 50%      1.000000    4.000000    148.500000  2803.500000     15.500000
# 75%      2.000000    8.000000    262.000000  3608.000000     17.175000
# max      3.000000    8.000000    455.000000  5140.000000     24.800000
#
#               year  Kilometer_per_liter
# count   398.000000           398.000000
# mean   1976.010050             9.997073
# std       3.697627             3.322917
# min    1970.000000             3.826293
# 25%    1973.000000             7.440015
# 50%    1976.000000             9.778305
# 75%    1979.000000            12.329168
# ...

# %%
vpp.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
vpp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
vpp.isnull().any()
# Out:
# origin                 False
# cylinders              False
# displacement           False
# horsepower             False
# weight                 False
# acceleration           False
# year                   False
# name                   False
# Kilometer_per_liter    False
# dtype: bool

# %%
vpp.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
vpp1 = vpd.drop(vpd.index[[32,126,330,336,354,374]])

# %%
vpp1.head()
# Out:
#    origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0       1          8         307.0        130    3504          12.0  1970
# 1       1          8         350.0        165    3693          11.5  1970
# 2       1          8         318.0        150    3436          11.0  1970
# 3       1          8         304.0        150    3433          12.0  1970
# 4       1          8         302.0        140    3449          10.5  1970
#
#                         name  Kilometer_per_liter
# 0  chevrolet chevelle malibu             7.652587
# 1          buick skylark 320             6.377156
# 2         plymouth satellite             7.652587
# 3              amc rebel sst             6.802299
# 4                ford torino             7.227443

# %%
x =vpp1.iloc[:,3].values
y = vpp1.iloc[:,8].values

# %%
vpp1.describe()
# Out:
#            origin   cylinders  displacement       weight  acceleration  \
# count  392.000000  392.000000    392.000000   392.000000    392.000000
# mean     1.576531    5.471939    194.411990  2977.584184     15.541327
# std      0.805518    1.705783    104.644004   849.402560      2.758864
# min      1.000000    3.000000     68.000000  1613.000000      8.000000
# 25%      1.000000    4.000000    105.000000  2225.250000     13.775000
# 50%      1.000000    4.000000    151.000000  2803.500000     15.500000
# 75%      2.000000    8.000000    275.750000  3614.750000     17.025000
# max      3.000000    8.000000    455.000000  5140.000000     24.800000
#
#               year  Kilometer_per_liter
# count   392.000000           392.000000
# mean   1975.979592             9.967885
# std       3.683737             3.318250
# min    1970.000000             3.826293
# 25%    1973.000000             7.227443
# 50%    1976.000000             9.672019
# 75%    1979.000000            12.329168
# ...

# %%
vpp1.info
# Out:
# <bound method DataFrame.info of      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0         1          8         307.0        130    3504          12.0  1970
# 1         1          8         350.0        165    3693          11.5  1970
# 2         1          8         318.0        150    3436          11.0  1970
# 3         1          8         304.0        150    3433          12.0  1970
# 4         1          8         302.0        140    3449          10.5  1970
# ..      ...        ...           ...        ...     ...           ...   ...
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
# ...

# %%
sns.distplot(vpp1['Kilometer_per_liter'],kde =False,bins = 10)

# %%
plt.figure(figsize=(40,30))
sns.countplot(y='Kilometer_per_liter',data =vpp1)

# %%
plt.figure(figsize=(20,40))
sns.barplot(x='Kilometer_per_liter',y='horsepower',data = vpp1)
plt.xlabel('Kilometer_per_liter',fontsize=30)
plt.ylabel('horsepower',fontsize = 30)
plt.xticks(fontsize =20)
plt.yticks(fontsize =20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-206-fc41790d667f> in <module>
#       1 plt.figure(figsize=(20,40))
# ----> 2 sns.barplot(x='Kilometer_per_liter',y='horsepower',data = vpp1)
#       3 plt.xlabel('Kilometer_per_liter',fontsize=30)
#       4 plt.ylabel('horsepower',fontsize = 30)
#       5 plt.xticks(fontsize =20)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ...

# %%
sns.heatmap(vpp1.corr())
plt.show()
plt.figure(figsize=(30,25))

# %%
x.ndim
# Out:
# 1

# %%
x1 = np.reshape(x,(-1,1))

# %%
x1.ndim
# Out:
# 2

# %%
x1
# Out:
# array([['130'],
#        ['165'],
#        ['150'],
#        ['150'],
#        ['140'],
#        ['198'],
#        ['220'],
#        ['215'],
#        ['225'],
#        ['190'],
#        ['170'],
#        ['160'],
#        ['150'],
#        ['225'],
#        ['95'],
#        ['95'],
#        ['97'],
#        ['85'],
#        ['88'],
#        ['46'],
#        ['87'],
#        ['90'],
#        ['95'],
#        ['113'],
#        ['90'],
#        ['215'],
#        ['200'],
#        ['210'],
#        ['193'],
#        ['88'],
#        ['90'],
#        ['95'],
#        ['100'],
#        ['105'],
#        ['100'],
#        ['88'],
#        ['100'],
#        ['165'],
#        ['175'],
#        ['153'],
#        ['150'],
#        ['180'],
#        ['170'],
#        ['175'],
#        ['110'],
#        ['72'],
#        ['100'],
#        ['88'],
#        ['86'],
#        ['90'],
#        ['70'],
#        ['76'],
#        ['65'],
#        ['69'],
#        ['60'],
#        ['70'],
# ...

# %%
y1 = np.reshape(y,(-1,1))

# %%
y1.ndim
# Out:
# 2

# %%
y1
# Out:
# array([[ 7.65258673],
#        [ 6.37715561],
#        [ 7.65258673],
#        [ 6.80229932],
#        [ 7.22744303],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 6.37715561],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [ 6.37715561],
#        [ 5.9520119 ],
#        [10.20344898],
#        [ 9.35316156],
#        [ 7.65258673],
#        [ 8.92801786],
#        [11.4788801 ],
#        [11.05373639],
#        [10.62859269],
#        [10.20344898],
#        [10.62859269],
#        [11.05373639],
#        [ 8.92801786],
#        [ 4.25143707],
#        [ 4.25143707],
#        [ 4.67658078],
#        [ 3.82629337],
#        [11.4788801 ],
#        [11.90402381],
#        [10.62859269],
#        [ 8.07773044],
#        [ 6.80229932],
#        [ 7.22744303],
#        [ 8.07773044],
#        [ 7.65258673],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
#        [ 5.9520119 ],
# ...

# %% [markdown]
# Split the Dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size =1/3,random_state =0)

# %% [markdown]
# Fitting Simple Linear Regression to the Training set

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Predicting the Test Set Result

# %%
y1_pred = lr.predict(x1_test)
y1_pred
# Out:
# array([[11.8302804 ],
#        [10.96115802],
#        [ 6.14755719],
#        [12.6325472 ],
#        [12.36512493],
#        [10.82744689],
#        [12.8331139 ],
#        [12.36512493],
#        [10.49316905],
#        [10.96115802],
#        [12.8331139 ],
#        [ 4.81044585],
#        [10.96115802],
#        [ 6.81611286],
#        [ 6.48183503],
#        [11.8302804 ],
#        [ 9.15605771],
#        [ 6.81611286],
#        [10.82744689],
#        [10.82744689],
#        [ 8.22007977],
#        [ 9.49033555],
#        [10.82744689],
#        [ 9.49033555],
#        [11.76342483],
#        [ 5.81327936],
#        [10.69373576],
#        [10.96115802],
#        [10.15889122],
#        [ 6.81611286],
#        [ 8.68806874],
#        [11.89713596],
#        [11.76342483],
#        [12.36512493],
#        [ 9.49033555],
#        [10.82744689],
#        [12.49883607],
#        [ 6.81611286],
#        [ 6.81611286],
#        [ 2.13622316],
#        [ 5.81327936],
# ...

# %%
plt.scatter(x1_train,y1_train,color = 'blue')
plt.plot(x1_train,lr.predict(x1_train),color = 'red')
plt.title('Kilometer per liter Vs Horsepower(Train Set)')
plt.xlabel('Kilometer per liter')
plt.ylabel('Horsepower')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-243-0cfa1ced01d8> in <module>
# ----> 1 plt.scatter(x1_train,y1_train,color = 'blue')
#       2 plt.plot(x1_train,lr.predict(x1_train),color = 'red')
#       3 plt.title('Kilometer per liter Vs Horsepower(Train Set)')
#       4 plt.xlabel('Kilometer per liter')
#       5 plt.ylabel('Horsepower')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2846         verts=verts, edgecolors=edgecolors,
#    2847         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2848         None else {}), **kwargs)
#    2849     sci(__ret)
#    2850     return __ret
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
